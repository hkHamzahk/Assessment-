# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized
# ![3 intro.png](attachment:90341c55-1124-40be-9644-5ae98fddd608.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1 )Python: Python is one of the most popular programming languages for data science. It has a rich ecosystem of libraries and frameworks such as NumPy, Pandas, Scikit-learn, and TensorFlow, which make it easy to perform data analysis, manipulate data, and build machine learning models.
#
# 2) R: R is a language specifically designed for statistical computing and graphics. It has extensive libraries and packages for statistical analysis, data visualization, and machine learning. R is widely used in academia and research fields.
#
# 3) SQL: SQL (Structured Query Language) is a language used for managing and manipulating relational databases. It is essential for data scientists who work with databases, as it allows them to extract, filter, and aggregate data efficiently. SQL is particularly useful for data preprocessing and data exploration tasks.

# %% [markdown]
# ![4-dslanguages.png](attachment:45552da0-1102-4864-bba9-67e6587fe648.png)

# %% [markdown]
# Data Science Tools
# Jupyter Notebook
# RStudio
# Apache Spark

# %% [markdown]
# ![ 6-dstools.png](attachment:b58408ea-ad47-434e-b548-f13213da8dca.png)

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![ 7-introarithmetic.png](attachment:c0f3494f-8c72-40d1-8f95-a26bb5a27e81.png)

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
#  This a simple arithmetic expression to mutiply then add integers

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:b7f1ae01-2aa1-4e2c-9acb-c38291b0f2d4.png)

# %%
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
#  This will convert 200 minutes to hours by diving by 60

# %% [markdown]
# ![9-hourstominutes.png](attachment:eff8bce7-b1b1-4311-9cd2-d2ed67baa6b8.png)

# %% [markdown]
# Objective

# %% [markdown]
#  List popular languages for Data Science.
# - Understand the purpose and functionality of Jupyter Notebook.
# - Explore data visualization libraries in Python, such as Matplotlib and Seaborn.
# - Learn about version control and GitHub for collaborative coding.
# - Introduce basic concepts of machine learning and its application in data science.

# %% [markdown]
# ![10-objectives.png](attachment:037b1198-ee13-4a6d-9f5e-7cdec99bcdcd.png)

# %% [markdown]
# Author  : Hamza khurshid

# %% [markdown]
# ![11-authordetails.png](attachment:3d67c1cb-435a-449e-9b85-96c4af5695df.png)
